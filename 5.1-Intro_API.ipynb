# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork1005-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>
#
# # Application Programming Interface
#
#
# Estimated time needed: **15** minutes
#
#
# ## Objectives
#
# After completing this lab you will be able to:
#
# * Create and Use APIs in Python

# %% [markdown]
# ### Introduction
#
# An API lets two pieces of software talk to each other. Just like a function,  you don’t have to know how the API works only its inputs and outputs.  An essential type of API is a REST API that allows you to access resources via the internet. In this lab, we will review the Pandas Library  in the context of an API, we will also review a basic REST API

# %% [markdown]
# ## Table of Contents
# <div class="alert alert-block alert-info" style="margin-top: 20px">
# <li><a href="#ref0">Pandas is an API</a></li>
# <li><a href="#ref1">REST APIs Basics  </a></li>
# <li><a href="#ref2">Quiz on Tuples</a></li>
#
# </div>
#
# <hr>

# %%
# !pip install pycoingecko
# !pip install plotly
# !pip install mplfinance
# !pip install --upgrade nbformat
# Out:
# Requirement already satisfied: pycoingecko in c:\users\joses\anaconda3\lib\site-packages (3.1.0)
# Requirement already satisfied: requests in c:\users\joses\anaconda3\lib\site-packages (from pycoingecko) (2.28.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\joses\anaconda3\lib\site-packages (from requests->pycoingecko) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\joses\anaconda3\lib\site-packages (from requests->pycoingecko) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\joses\anaconda3\lib\site-packages (from requests->pycoingecko) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\joses\anaconda3\lib\site-packages (from requests->pycoingecko) (2022.9.14)
# Requirement already satisfied: plotly in c:\users\joses\anaconda3\lib\site-packages (5.9.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\joses\anaconda3\lib\site-packages (from plotly) (8.0.1)
# Requirement already satisfied: mplfinance in c:\users\joses\anaconda3\lib\site-packages (0.12.9b7)
# Requirement already satisfied: matplotlib in c:\users\joses\anaconda3\lib\site-packages (from mplfinance) (3.5.2)
# Requirement already satisfied: pandas in c:\users\joses\anaconda3\lib\site-packages (from mplfinance) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\joses\anaconda3\lib\site-packages (from matplotlib->mplfinance) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\joses\anaconda3\lib\site-packages (from matplotlib->mplfinance) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\joses\anaconda3\lib\site-packages (from matplotlib->mplfinance) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\joses\anaconda3\lib\site-packages (from matplotlib->mplfinance) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\joses\anaconda3\lib\site-packages (from matplotlib->mplfinance) (0.11.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\joses\anaconda3\lib\site-packages (from matplotlib->mplfinance) (1.21.5)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\joses\anaconda3\lib\site-packages (from matplotlib->mplfinance) (9.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\joses\anaconda3\lib\site-packages (from matplotlib->mplfinance) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\joses\anaconda3\lib\site-packages (from pandas->mplfinance) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\joses\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->mplfinance) (1.16.0)
# Requirement already satisfied: nbformat in c:\users\joses\anaconda3\lib\site-packages (5.7.3)
# Requirement already satisfied: jupyter-core in c:\users\joses\anaconda3\lib\site-packages (from nbformat) (4.11.1)
# Requirement already satisfied: fastjsonschema in c:\users\joses\anaconda3\lib\site-packages (from nbformat) (2.16.2)
# Requirement already satisfied: traitlets>=5.1 in c:\users\joses\anaconda3\lib\site-packages (from nbformat) (5.1.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\joses\anaconda3\lib\site-packages (from nbformat) (4.16.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\joses\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\joses\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat) (0.18.0)
# Requirement already satisfied: pywin32>=1.0 in c:\users\joses\anaconda3\lib\site-packages (from jupyter-core->nbformat) (302)

# %% [markdown]
# <h2 id="PandasAPI">Pandas is an API </h2>

# %% [markdown]
# Pandas is actually a set of software components , much of  which is not even written in Python.

# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go
from plotly.offline import plot
import matplotlib.pyplot as plt
import datetime
from pycoingecko import CoinGeckoAPI
from mplfinance.original_flavor import candlestick2_ohlc

# %% [markdown]
# You create a dictionary, this is just data.

# %%
dict_={'a':[11,21,31],'b':[12,22,32]}

# %% [markdown]
# When you create a Pandas object with the Dataframe constructor in API lingo, this is an "instance". The data in the dictionary is passed along to the pandas API. You then use the dataframe to communicate with the API.

# %%
df=pd.DataFrame(dict_)
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%205/images/pandas_api.png" width="800," align="center" alt="logistic regression block diagram">

# %% [markdown]
# When you call the method head the dataframe communicates with the API displaying the first few rows of the dataframe.

# %%
df.head()
# Out:
#     a   b
# 0  11  12
# 1  21  22
# 2  31  32

# %% [markdown]
# When you call the method mean,the API will calculate the mean and return the value.

# %%
df.mean()
# Out:
# a    21.0
# b    22.0
# dtype: float64

# %% [markdown]
# <h2 id="ref1">REST APIs</h2>

# %% [markdown]
# Rest API’s function by sending a request,  the request is communicated via HTTP message. The HTTP message usually contains a JSON file. This contains instructions for what operation we would like the service or resource to perform. In a similar manner, API returns a response, via an HTTP message, this response is usually contained within a JSON.
#
# In cryptocurrency a popular method to display the movements of the price of a currency.
#
# ![Example Candlestick Graph](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%205/candlestick.png)
#
# Here is a description of the candle sticks.
#
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%205/explanation.png" alt="Candle Stick Definition" width="800" height="600">
#
# In this lab, we will be using the <a href=https://www.coingecko.com/en/api?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork1005-2022-01-01>CoinGecko API</a> to create one of these candlestick graphs for Bitcoin. We will use the API to get the price data for 30 days with 24 observation per day, 1 per hour. We will find the max, min, open, and close price per day meaning we will have 30 candlesticks and use that to generate the candlestick graph. Although we are using the CoinGecko API we will use a Python client/wrapper for the API called <a href=https://github.com/man-c/pycoingecko>PyCoinGecko</a>. PyCoinGecko will make performing the requests easy and it will deal with the enpoint targeting.

# %% [markdown]
# Lets start off by getting the data we need. Using the <code>get_coin_market_chart_by_id(id, vs_currency, days)</code>. <code>id</code> is the name of the coin you want, <code>vs_currency</code> is the currency you want the price in, and <code>days</code> is how many days back from today you want.

# %%
cg = CoinGeckoAPI()

bitcoin_data = cg.get_coin_market_chart_by_id(id='bitcoin', vs_currency='usd', days=30)

# %%
type(bitcoin_data )
# Out:
# dict

# %% [markdown]
# The response we get is in the form of a JSON which includes the price, market caps, and total volumes along with timestamps for each observation. We are focused on the prices so we will select that data.

# %%
bitcoin_price_data = bitcoin_data['prices']

bitcoin_price_data[0:5]
# Out:
# [[1671735710932, 16620.811703178],
#  [1671739311897, 16656.8058694788],
#  [1671742824800, 16764.61277070444],
#  [1671746466540, 16793.457692361906],
#  [1671750099155, 16800.94753254382]]

# %% [markdown]
# Finally lets turn this data into a Pandas DataFrame.

# %%
data = pd.DataFrame(bitcoin_price_data, columns=['TimeStamp', 'Price'])
data
# Out:
#          TimeStamp         Price
# 0    1671735710932  16620.811703
# 1    1671739311897  16656.805869
# 2    1671742824800  16764.612771
# 3    1671746466540  16793.457692
# 4    1671750099155  16800.947533
# ..             ...           ...
# 718  1674313261606  22959.012989
# 719  1674316871672  23137.819619
# 720  1674320578580  23200.270789
# 721  1674324132171  23259.491423
# 722  1674327295000  23211.869954
#
# [723 rows x 2 columns]

# %% [markdown]
# Now that we have the DataFrame we will convert the timestamp to datetime and save it as a column called <code>Date</code>. We will map our <code>unix_to_datetime</code> to each timestamp and convert it to a readable datetime.

# %%
#"lamda d:" is an anonymous function and "datetime.date.fromtimestamp()" converts timestamp into an object date (represents a date). 
    #The TimeStamp values are in miliseconds, that's why we have to divide by 1000

data['date'] = data['TimeStamp'].apply(lambda d: datetime.date.fromtimestamp(d/1000.0)) 
data

# date_timestamp = 1671735710932
# date_normal = datetime.date.fromtimestamp(1671735710932/1000.0)
# date_normal
# Out:
#          TimeStamp         Price        date
# 0    1671735710932  16620.811703  2022-12-22
# 1    1671739311897  16656.805869  2022-12-22
# 2    1671742824800  16764.612771  2022-12-22
# 3    1671746466540  16793.457692  2022-12-22
# 4    1671750099155  16800.947533  2022-12-23
# ..             ...           ...         ...
# 718  1674313261606  22959.012989  2023-01-21
# 719  1674316871672  23137.819619  2023-01-21
# 720  1674320578580  23200.270789  2023-01-21
# 721  1674324132171  23259.491423  2023-01-21
# 722  1674327295000  23211.869954  2023-01-21
#
# [723 rows x 3 columns]

# %% [markdown]
# Using this modified dataset we can now group by the <code>Date</code> and find the min, max, open, and close for the candlesticks.

# %%
candlestick_data = data.groupby(data.date, as_index=False).agg({"Price": ['min', 'max', 'first', 'last']})

candlestick_data
# Out:
#           date         Price
#                          min           max         first          last
# 0   2022-12-22  16620.811703  16793.457692  16620.811703  16793.457692
# 1   2022-12-23  16800.389952  16891.297302  16800.947533  16825.560755
# 2   2022-12-24  16791.455439  16859.602707  16802.190131  16838.558479
# 3   2022-12-25  16769.859044  16849.932722  16847.802248  16820.196694
# 4   2022-12-26  16813.158457  16895.732317  16813.158457  16839.488816
# 5   2022-12-27  16647.597013  16895.753540  16843.692990  16721.330917
# 6   2022-12-28  16514.471146  16717.054806  16701.282355  16514.471146
# 7   2022-12-29  16515.817326  16659.638928  16515.817326  16598.929697
# 8   2022-12-30  16464.043979  16646.170466  16624.522841  16588.158247
# 9   2022-12-31  16544.737138  16611.607871  16589.023380  16551.805376
# 10  2023-01-01  16518.854339  16614.184021  16521.815520  16604.227756
# 11  2023-01-02  16573.799637  16743.523050  16605.620779  16743.523050
# 12  2023-01-03  16625.153163  16750.982601  16715.600424  16667.878268
# 13  2023-01-04  16659.853022  16972.972810  16677.789389  16824.227072
# 14  2023-01-05  16792.659516  16861.252341  16826.448586  16849.829633
# 15  2023-01-06  16726.147662  16973.129952  16838.236884  16929.611543
# 16  2023-01-07  16922.206718  16973.698807  16964.318089  16943.335749
# 17  2023-01-08  16931.037714  16974.138894  16944.759782  16959.063193
# 18  2023-01-09  16984.392483  17359.371371  16984.392483  17184.023314
# 19  2023-01-10  17194.909329  17489.899095  17212.246419  17489.899095
# 20  2023-01-11  17343.596846  17558.744754  17438.650417  17558.744754
# 21  2023-01-12  17548.486914  18975.992189  17548.486914  18854.626868
# 22  2023-01-13  18792.320558  19802.819123  18925.368027  19802.819123
# 23  2023-01-14  19932.618003  21083.034367  19932.618003  20879.331767
# 24  2023-01-15  20606.546176  20956.258670  20944.019263  20903.899112
# 25  2023-01-16  20751.537690  21339.084565  20812.144522  21140.667769
# 26  2023-01-17  21035.724169  21356.441022  21196.704354  21320.630118
# 27  2023-01-18  20532.907208  21470.684643  21247.502058  20792.951371
# 28  2023-01-19  20699.215560  21099.939721  20831.950823  20935.470397
# 29  2023-01-20  20950.344850  22327.516533  21080.253856  22327.516533
# 30  2023-01-21  22548.070087  23259.491423  22621.809071  23211.869954

# %% [markdown]
# Finally we are now ready to use plotly to create our Candlestick Chart.

# %%
fig = go.Figure(data=[go.Candlestick(x=candlestick_data['date'],
                open=candlestick_data['Price']['first'], 
                high=candlestick_data['Price']['max'],
                low=candlestick_data['Price']['min'], 
                close=candlestick_data['Price']['last'])
                ])

fig.update_layout(xaxis_rangeslider_visible=False)

fig.show()

# %% [markdown]
# ## Authors:
#
#
# ## Change Log
#
#
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2020-11-23 | 3.0 | Azim Hirjani | New API |
# | 2020-09-09 | 2.1 | Malika Singla | Spell Check |
# | 2020-08-26  | 2.0  | Lavanya | Moved lab to course repo in GitLab |
# |   |   |   |   |
#
#
#
#
# <hr/>
#
# ## <h3 align="center"> © IBM Corporation 2020. All rights reserved. <h3/>
